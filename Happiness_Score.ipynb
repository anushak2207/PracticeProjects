# %% [markdown]
# ##### Happiness_Score_Dataset :
#
# Data_Description :
#
#         The task is to train and get the happiness score of the countries by using the indipendant variables like GDP per capita, Family, Health,Freedom,Trust and generocity.
#         The dataset contails 158 Coutries happiness factors. The Happiness score is meassure 10 to 0. 10 as high and 0 as low happiness score.

# %%
#Importing Required Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.linear_model import LinearRegression

# %%
#Loading the Dataset
#df=pd.read_csv("https://github.com/dsrscientist/DSData/blob/master/happiness_score_dataset.csv")

df = pd.read_csv("happiness_score_dataset.csv")
df.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# ...

# %%
df.tail(10)
# Out:
#           Country                           Region  Happiness Rank  \
# 148          Chad               Sub-Saharan Africa             149
# 149        Guinea               Sub-Saharan Africa             150
# 150   Ivory Coast               Sub-Saharan Africa             151
# 151  Burkina Faso               Sub-Saharan Africa             152
# 152   Afghanistan                    Southern Asia             153
# 153        Rwanda               Sub-Saharan Africa             154
# 154         Benin               Sub-Saharan Africa             155
# 155         Syria  Middle East and Northern Africa             156
# 156       Burundi               Sub-Saharan Africa             157
# 157          Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 148            3.667         0.03830                   0.34193  0.76062
# 149            3.656         0.03590                   0.17417  0.46475
# ...

# %%
# checking the data dimesion 
df.shape
# Out:
# (158, 12)

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
sns.heatmap(df.isnull())
plt.title('Null Values')
plt.show()

# %% [markdown]
# There is no null values in the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
corr_mat=df.corr()
plt.figure(figsize=[12,12])
sns.heatmap(corr_mat, annot=True)
plt.title("Correlation Matrix")
plt.show()

# %%
corr_mat=df.corr()
corr_mat["Happiness Score"].sort_values(ascending=False)
# Out:
# Happiness Score                  1.000000
# Economy (GDP per Capita)         0.780966
# Family                           0.740605
# Health (Life Expectancy)         0.724200
# Freedom                          0.568211
# Dystopia Residual                0.530474
# Trust (Government Corruption)    0.395199
# Generosity                       0.180319
# Standard Error                  -0.177254
# Happiness Rank                  -0.992105
# Name: Happiness Score, dtype: float64

# %% [markdown]
# As we can see above, Economy(GDP per Capita), Family, Health(Life Expectancy) and Freedom is +vely correlated with Happiness Score

# %% [markdown]
# Lets Update the Column names with short names for easier writing
#
# Happiness Score : HScore
#
# Happiness Rank  : HRank
#
# Economy (GDP per Capita) : Economy
#
# Health (Life Expectancy) : Health
#
# Trust (Government Corruption) : Trust

# %%
hdf = df.rename(columns={'Happiness Score':'HScore','Happiness Rank':'HRank','Economy (GDP per Capita)':'Economy', 'Health (Life Expectancy)':'Health','Trust (Government Corruption)':'Trust'})
hdf
# Out:
#      Economy   Family   Health  Freedom    Trust  Generosity  HRank  HScore
# 0    1.39651  1.34951  0.94143  0.66557  0.41978     0.29678      1   7.587
# 1    1.30232  1.40223  0.94784  0.62877  0.14145     0.43630      2   7.561
# 2    1.32548  1.36058  0.87464  0.64938  0.48357     0.34139      3   7.527
# 3    1.45900  1.33095  0.88521  0.66973  0.36503     0.34699      4   7.522
# 4    1.32629  1.32261  0.90563  0.63297  0.32957     0.45811      5   7.427
# ..       ...      ...      ...      ...      ...         ...    ...     ...
# 153  0.22208  0.77370  0.42864  0.59201  0.55191     0.22628    154   3.465
# 154  0.28665  0.35386  0.31910  0.48450  0.08010     0.18260    155   3.340
# 155  0.66320  0.47489  0.72193  0.15684  0.18906     0.47179    156   3.006
# 156  0.01530  0.41587  0.22396  0.11850  0.10062     0.19727    157   2.905
# 157  0.20868  0.13995  0.28443  0.36453  0.10731     0.16681    158   2.839
#
# [158 rows x 8 columns]

# %% [markdown]
# ###### Outliers
#
# Checking for the Outliers

# %%
hdf.iloc[:,0:6].boxplot()
plt.show()

# %% [raw]
# We can see, in Family there 3 outliers which can be ignored and in Trust there are many outliers which can also be included in the dataset so as to avoid the data loss.
# Ignoring Generosity as there is 0.1 correlation between HScore and generosity

# %% [markdown]
# ###### Skewness
#
# Checking for the Skewness

# %%
df.plot(kind='density', subplots=True,sharex=False,legend=False, fontsize=1,figsize=(18,12),layout=(4,8))
plt.show()

# %%
#sns.pairplot(hdf)
#plt.show()

# %%
x=hdf.drop('HScore',axis=1)
x
# Out:
#      Economy   Family   Health  Freedom    Trust  Generosity  HRank
# 0    1.39651  1.34951  0.94143  0.66557  0.41978     0.29678      1
# 1    1.30232  1.40223  0.94784  0.62877  0.14145     0.43630      2
# 2    1.32548  1.36058  0.87464  0.64938  0.48357     0.34139      3
# 3    1.45900  1.33095  0.88521  0.66973  0.36503     0.34699      4
# 4    1.32629  1.32261  0.90563  0.63297  0.32957     0.45811      5
# ..       ...      ...      ...      ...      ...         ...    ...
# 153  0.22208  0.77370  0.42864  0.59201  0.55191     0.22628    154
# 154  0.28665  0.35386  0.31910  0.48450  0.08010     0.18260    155
# 155  0.66320  0.47489  0.72193  0.15684  0.18906     0.47179    156
# 156  0.01530  0.41587  0.22396  0.11850  0.10062     0.19727    157
# 157  0.20868  0.13995  0.28443  0.36453  0.10731     0.16681    158
#
# [158 rows x 7 columns]

# %%
y=hdf['HScore']
y
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 153    3.465
# 154    3.340
# 155    3.006
# 156    2.905
# 157    2.839
# Name: HScore, Length: 158, dtype: float64

# %%
#Checking the Skewness
x.skew()
# Out:
# Economy      -0.317575
# Family       -1.006893
# Health       -0.705328
# Freedom      -0.413462
# Trust         1.385463
# Generosity    1.001961
# HRank         0.000418
# dtype: float64

# %%
from sklearn.preprocessing import power_transform
df_new=power_transform(x)   #Now the data is in ND Array form, 
df_new=pd.DataFrame(df_new, columns=x.columns)  # Converting the data to dataframe
df_new.skew()
# Out:
# Economy      -0.127233
# Family       -0.169651
# Health       -0.183181
# Freedom      -0.080728
# Trust         0.185965
# Generosity    0.013320
# HRank        -0.264365
# dtype: float64

# %%
df_new.plot(kind='density', subplots=True,sharex=False,legend=False, fontsize=1,figsize=(18,12),layout=(4,8))
plt.show()

# %%
df_new.head()
# Out:
#     Economy    Family    Health   Freedom     Trust  Generosity     HRank
# 0  1.446061  1.669206  1.491765  1.756335  1.773991    0.622391 -2.063414
# 1  1.173321  2.012132  1.532348  1.439946  0.315993    1.480995 -2.008498
# 2  1.239836  1.739586  1.085223  1.615733  1.906792    0.927973 -1.958574
# 3  1.630246  1.553118  1.147600  1.792821  1.624007    0.964080 -1.912062
# 4  1.242168  1.501726  1.270179  1.475479  1.503484    1.592224 -1.868100

# %% [markdown]
# ###### Finding the Best Random State :

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

maxAcc=0
maxRS=0
for i in range(1,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i) #Train/Test Splitting
    LR=LinearRegression()           #LinearRegression
    LR.fit(x_train,y_train)         #Fitting the Model
    pred=LR.predict(x_test)         #Predition
    acc=LR.score(x_train,y_train)   #Accuracy score
    if acc>maxAcc:
        maxAcc=acc
        maxRS=i
        
print("Best Acc:",maxAcc,"on Rand State ",maxRS)
# Out:
# Best Acc: 0.99050619305459 on Rand State  79

# %% [markdown]
# ###### Creating Train Test split  using best random state

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=79)

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
#The Coefficients : 
print('Coefficients :',LR.coef_)
print('Intercepts :',LR.intercept_)
# Out:
# Coefficients : [ 0.07339683  0.00811813 -0.06158039 -0.06879708  0.33102627  0.32174571
#  -0.02378414]
# Intercepts : 7.158022141460042

# %%
#Prediction :

pred=LR.predict(x_test)
pred
# Out:
# array([6.97330435, 6.51746412, 4.96880084, 3.52767548, 4.51805094,
#        5.03100212, 6.86970088, 5.25022683, 3.46317919, 4.47818494,
#        3.86580132, 5.4781862 , 4.34631553, 3.65936134, 4.39560589,
#        4.93846603, 6.30890325, 5.61537463, 5.38152591, 3.50324553,
#        3.89440778, 5.70238753, 4.96203473, 4.02531481, 3.97525136,
#        5.63321084, 6.44746851, 5.51595189, 5.95604798, 6.17911808,
#        6.02349006, 6.86332301])

# %%
#AccuracyScore :

r2_score=LR.score(x_train,y_train)
r2_score
# Out:
# 0.99050619305459

# %%
import joblib
file_name="Happiness_Score.obj"
joblib.dump(LR,open(file_name,'wb'))

# %%
#Lets test a sample : 
#p=joblib.load(file_name)

# %%
#p.predict([[0.446061,0.669206,0.491765,1.756335,1.773991,0.622391,2.063414]])
# Out:
# array([7.78349324])

# %%
Conclusion :
a=np.array(y_test)
b=np.array(LR.predict(x_test))
cdf=pd.DataFrame({'Original':a,'Predicted':b},index=range(len(a)))
cdf
# Out:
#     Original  Predicted
# 0      7.226   6.973304
# 1      6.574   6.517464
# 2      4.949   4.968801
# 3      3.340   3.527675
# 4      4.518   4.518051
# 5      4.971   5.031002
# 6      6.798   6.869701
# 7      5.057   5.250227
# 8      2.839   3.463179
# 9      4.550   4.478185
# 10     3.904   3.865801
# 11     5.253   5.478186
# 12     4.512   4.346316
# 13     3.006   3.659361
# 14     4.517   4.395606
# 15     4.885   4.938466
# 16     6.269   6.308903
# 17     5.477   5.615375
# 18     5.194   5.381526
# 19     2.905   3.503246
# 20     3.931   3.894408
# 21     5.474   5.702388
# 22     4.959   4.962035
# 23     4.194   4.025315
# 24     4.077   3.975251
# 25     5.589   5.633211
# 26     6.477   6.447469
# 27     5.429   5.515952
# 28     5.855   5.956048
# 29     5.995   6.179118
# 30     5.878   6.023490
# 31     6.937   6.863323

# %% [raw]
# We can see some error after the decimal point.
